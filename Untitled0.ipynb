# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitha401/linear-regression/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
fron sklearn.cluster import AgglomerativeClustering

df=pd.read_csv("csv")

x=df[['Annual_Income_(k$)','spredading score']]

agg_model = AgglomerativeClustring(n_clusters=3)

df['cluster']=agg_model.fit_predict(x)

plt.scatter(x['annual Income'],x['spending Score'],c=df['cluster'],cmap='raimbow')
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.tittle("Agglometrative Clustering Example")
plt.show()

df.to_csv("agglo_clustared_data.csv",index=False)
print("Agglomerative clustred dataset saved as 'agglo_clustred_data.csv'")
